# %% [markdown]
# ## Title
# Principal Components Analysis
#
# ## Description :
# This exercise demonstrates the effect of scaling for Principal Components Analysis:
#
# After this exercise you should see following two plots:
#
# <img src="../fig/fig1.png" style="width: 500px;">
# <img src="../fig/fig2.png" style="width: 500px;">
#
#
# ## Hints:
# <a href="https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html" target="_blank">Principal Components Analysis</a>
#
# <a href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html" target="_blank">Standard scaler</a>
#
# Refer to lecture notebook.
#
# Do not change any other code except the blanks.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
df = pd.read_csv('../data/data2.csv')
display(df.describe())
feature_names = df.columns
df.head()
# Out:
#                a1          a2          a3          a4
# count  200.000000  200.000000  200.000000  200.000000
# mean    -0.857044    4.212110    0.031775   -0.021885
# std    421.494274  420.739376    4.074328    4.183966
# min   -605.324722 -646.589819   -6.809775   -6.249051
# 25%   -422.060527 -399.810929   -3.883741   -4.010144
# 50%     46.593553   40.746538   -0.333865   -0.071820
# 75%    405.738027  403.029485    3.981151    4.128475
# max    618.733299  629.307897    6.430227    6.691714
#            a1          a2        a3        a4
# 0  343.952435  619.881035  3.926444  5.074012
# 1  376.982251  531.241298  2.831349  3.972653
# 2  555.870831  373.485494  3.365252  3.966670
# 3  407.050839  454.319406  3.971158  2.483932
# 4  412.928774  358.566005  4.670696  4.790385

# %%
### edTest(test_pca_noscaling) ###
#Fit and Plot the first 2 principal components (no scaling)
fitted_pca = PCA().fit(df)
pca_result = fitted_pca.transform(df)
plt.scatter(pca_result[:,0],pca_result[:,1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA - No scaling")
pd.DataFrame(pca_result).head
# Out:
# <bound method NDFrame.head of               0           1         2         3
# 0    678.977178  192.188906  5.979567 -0.774691
# 1    639.736977  106.114193  4.664438 -0.844127
# 2    654.905761 -131.913223  5.720686 -0.633220
# 3    606.678891   30.427309  4.603371  0.963517
# 4    543.194742  -41.489896  6.934763 -0.183668
# ..          ...         ...       ...       ...
# 195 -320.453944  -38.786646 -5.849317 -1.469177
# 196 -580.224525 -101.366818 -5.322542 -0.421290
# 197 -596.869165  144.108920 -7.896028 -0.957026
# 198 -700.368968  -50.190420 -4.698200  0.688387
# 199 -677.004703   54.517366 -4.221614  0.954621
#
# [200 rows x 4 columns]>

# %%
pc1_weights = pd.Series(fitted_pca.components_[0], index=feature_names)

# %%
pc1_loadings = pd.Series(fitted_pca.components_[0],
    index=feature_names)

print(pc1_loadings.sort_values(ascending=False))
# Out:
# a1    0.707777
# a2    0.706436
# a3   -0.000014
# a4   -0.000324
# dtype: float64

# %%
### edTest(test_pca_scaled) ###
#scale the data and plot first 2 principal components
scaled_df = StandardScaler().fit_transform(df)
fitted_pca = PCA().fit(scaled_df)
pca_result = fitted_pca.transform(scaled_df)
plt.scatter(pca_result[:,0],pca_result[:,1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA - with scaled data");

# %%
pc1_loadings = pd.Series(fitted_pca.components_[0],
    index=feature_names)

print(pc1_loadings.sort_values(ascending=False))
# Out:
# a1    0.509803
# a2    0.501688
# a3   -0.482867
# a4   -0.505222
# dtype: float64
